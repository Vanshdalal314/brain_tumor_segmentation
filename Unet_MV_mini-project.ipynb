# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.6.6.tar.gz (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (2022.9.14)
# Requirement already satisfied: python-dateutil in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (2.7.5)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (2.28.1)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-slugify in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (6.1.2)
# Requirement already satisfied: urllib3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (1.26.11)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.10/site-packages (from kaggle) (5.0.1)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.10/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->kaggle) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->kaggle) (2.1.1)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.6.6-py3-none-any.whl size=111946 sha256=8d712aaec87f1de8e04fd49319bf727285cefe9e6fa7e6f31608d97036659fe6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/53/34/8c/8ca3450d17206d9e37e1ee3aeb47cbb2873d22a9e0c60eb137
# Successfully built kaggle
# Installing collected packages: kaggle
# Successfully installed kaggle-1.6.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 18.5 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Downloading flatbuffers-24.3.7-py2.py3-none-any.whl (26 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 9.6 MB/s eta 0:00:00
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 60.5 MB/s eta 0:00:00:00:01
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 23.6 MB/s eta 0:00:0000:0100:01
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 90.5 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (4.21.12)
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (4.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (1.54.2)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 65.7 MB/s eta 0:00:00:00:01
# Collecting keras>=3.0.0 (from tensorflow)
#   Downloading keras-3.0.5-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 91.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: rich in /srv/conda/envs/notebook/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (13.4.2)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Collecting dm-tree (from keras>=3.0.0->tensorflow)
#   Downloading dm_tree-0.1.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.5.7)
# Requirement already satisfied: markdown>=2.6.8 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.4.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 47.3 MB/s eta 0:00:00:00:010:01
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow)
#   Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)
# Installing collected packages: namex, libclang, flatbuffers, dm-tree, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, opt-einsum, ml-dtypes, h5py, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 dm-tree-0.1.8 flatbuffers-24.3.7 gast-0.5.4 google-pasta-0.2.0 h5py-3.10.0 keras-3.0.5 libclang-16.0.6 ml-dtypes-0.3.2 namex-0.0.7 opt-einsum-3.3.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-io-gcs-filesystem-0.36.0 termcolor-2.4.0 werkzeug-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydot
# Out:
# Collecting pydot
#   Using cached pydot-2.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyparsing>=3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pydot) (3.1.0)
# Installing collected packages: pydot
# Successfully installed pydot-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# Requirement already satisfied: numpy>=1.21.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from opencv-python) (1.24.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python-headless
# Out:
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
# Requirement already satisfied: numpy>=1.21.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from opencv-python-headless) (1.24.3)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %%
# !apt-get update
# Out:
# Reading package lists... Done
# E: List directory /var/lib/apt/lists/partial is missing. - Acquire (13: Permission denied)

# %%
import os

# Set Kaggle API credentials using environment variables
os.environ['KAGGLE_USERNAME'] = 'biyawalavaibhav'
os.environ['KAGGLE_KEY'] = 'ac6088d223fe39a93dd9e5a125562443'

# %%
# !kaggle datasets download -d tinashri/brain-tumor-dataset-includes-the-mask-and-images
# Out:
# Downloading brain-tumor-dataset-includes-the-mask-and-images.zip to /home/jovyan/PlanetaryComputerExamples
# 100%|███████████████████████████████████████▊| 311M/312M [00:07<00:00, 45.3MB/s]
# 100%|████████████████████████████████████████| 312M/312M [00:08<00:00, 40.7MB/s]

# %%
import zipfile

# Specify the path to the downloaded zip file
zip_file_path = '/home/jovyan/PlanetaryComputerExamples/brain-tumor-dataset-includes-the-mask-and-images.zip'

# Specify the directory where you want to extract the contents
extract_to_directory = '/home/jovyan/PlanetaryComputerExamples/brain_tumor_dataset'

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_directory)

# Optional: List the extracted files
extracted_files = os.listdir(extract_to_directory)
print("Extracted files:", extracted_files)
# Out:
# Extracted files: ['data', 'predict_all.py']

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
from sklearn.model_selection import train_test_split

# %%
# Define image and mask directories
image_directory = "brain_tumor_dataset/data/data/images/"
mask_directory = "brain_tumor_dataset/data/data/masks"

# Create lists of file paths for images and masks
image_file_paths = [os.path.join(image_directory, filename) for filename in os.listdir(image_directory)]
mask_file_paths = [os.path.join(mask_directory, filename) for filename in os.listdir(mask_directory)]

# Split the lists into training and testing sets
train_image_paths, test_image_paths, train_mask_paths, test_mask_paths = train_test_split(
    image_file_paths, mask_file_paths, test_size=0.2, random_state=42
)
def resize(input_image, input_mask):
    input_image = tf.image.resize(input_image, (128, 128), method="nearest")
    input_mask = tf.image.resize(input_mask, (128, 128), method="nearest")
    return input_image, input_mask

def enhance_contrast(input_image):
    # Apply per-image standardization
    enhanced_image = tf.image.per_image_standardization(input_image)
    return enhanced_image

def normalize(input_image, input_mask):
    input_image = tf.cast(input_image, tf.float32) / 255.0
    input_mask = tf.cast(input_mask, tf.float32) / 255.0
    return input_image, input_mask

# Define functions to load images and masks from file and preprocess them
def load_image_and_mask(image_path, mask_path):
    input_image = tf.io.read_file(image_path)
    input_image = tf.image.decode_png(input_image, channels=3)
    input_mask = tf.io.read_file(mask_path)
    input_mask = tf.image.decode_png(input_mask, channels=1)
    input_image, input_mask = resize(input_image, input_mask)
    input_image=enhance_contrast(input_image)
    input_image, input_mask = normalize(input_image, input_mask)
    return input_image, input_mask


# Create TensorFlow datasets from the lists of file paths
train_dataset = tf.data.Dataset.from_tensor_slices((train_image_paths, train_mask_paths))
test_dataset = tf.data.Dataset.from_tensor_slices((test_image_paths, test_mask_paths))

# Map the loading and preprocessing functions to the datasets
train_dataset = train_dataset.map(load_image_and_mask, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.map(load_image_and_mask, num_parallel_calls=tf.data.AUTOTUNE)

# %%
for image, mask in train_dataset.take(10):
    print("Image shape:", image.shape)
    print("Mask shape:", mask.shape)
# Out:
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)
# Image shape: (128, 128, 3)
# Mask shape: (128, 128, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np

def display(display_list):
    plt.figure(figsize=(5, 5))  # Adjust the figsize if needed
    title = ["Input Image", "True Mask"]
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap='gray')
        plt.axis("off")
    plt.show()

# Create an iterator for the test_batches dataset
test_iterator = iter(test_dataset.take(10))

# Iterate through batches and display images
for _ in range(10):  # You can change the range to display a different number of batches
    # Fetch a sample batch
    sample_batch = next(test_iterator)
    sample_image, sample_mask = sample_batch

    # Display the sample image and mask
    display([sample_image, sample_mask])

# %%
def double_conv_block(x, n_filters):

    # Conv2D then ReLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
    # Conv2D then ReLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate 
    x = layers.concatenate([x, conv_features])
    # dropout
    x = layers.Dropout(0.3)(x)
    # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)

    return x

# %%
import shutil
c="brain_tumor_dataset/data/data/masks/.ipynb_checkpoints"
if os.path.exists(c):
    shutil.rmtree(c)

# %% [markdown]
# ## Build the U-Net Model

# %%
def build_unet_model():

    # inputs
    inputs = layers.Input(shape=(128,128,3))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    outputs = layers.Conv2D(3, 1, padding="same", activation = "softmax")(u9)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %%
unet_model = build_unet_model()

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 64)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 128)  0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 256)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 512)  2359808     ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 512)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 1024)   4719616     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  4719104    ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 1024  0           ['concatenate[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  4719104     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  2359808     ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  1179904    ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 512)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  1179904     ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  295040     ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 256)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  295040      ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  73792      ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 12  0           ['concatenate_3[0][0]']
#                                 8)
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  73792       ['dropout_7[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 3)  195         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 34,513,475
# Trainable params: 34,513,475
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(unet_model, show_shapes=True)

# %%
unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                   loss="sparse_categorical_crossentropy",
                   metrics="accuracy")

# %%
NUM_EPOCHS = 100  # Set the number of epochs
BATCH_SIZE = 32
BUFFER_SIZE = 100

train_batches = train_dataset.take(2000).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(train_batches,len(train_batches))
validation_batches = train_dataset.skip(2000).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(validation_batches,len(validation_batches))

# Train the model with the modified parameters
model_history = unet_model.fit(train_batches,
                               epochs=NUM_EPOCHS,
                              validation_data=validation_batches )
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None))> 63
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name=None))> 15
# Epoch 1/100
# 63/63 [==============================] - 44s 707ms/step - loss: 0.3176 - accuracy: 0.9829 - val_loss: 0.0610 - val_accuracy: 0.9838
# Epoch 2/100
# 63/63 [==============================] - 31s 483ms/step - loss: 0.0620 - accuracy: 0.9829 - val_loss: 0.0545 - val_accuracy: 0.9838
# Epoch 3/100
# 63/63 [==============================] - 31s 488ms/step - loss: 0.0579 - accuracy: 0.9829 - val_loss: 0.0563 - val_accuracy: 0.9838
# Epoch 4/100
# 63/63 [==============================] - 31s 491ms/step - loss: 0.0540 - accuracy: 0.9829 - val_loss: 0.0495 - val_accuracy: 0.9838
# Epoch 5/100
# 63/63 [==============================] - 31s 494ms/step - loss: 0.0519 - accuracy: 0.9829 - val_loss: 0.0513 - val_accuracy: 0.9838
# Epoch 6/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0530 - accuracy: 0.9829 - val_loss: 0.0463 - val_accuracy: 0.9840
# Epoch 7/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0469 - accuracy: 0.9847 - val_loss: 0.0464 - val_accuracy: 0.9865
# Epoch 8/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0436 - accuracy: 0.9858 - val_loss: 0.0400 - val_accuracy: 0.9874
# Epoch 9/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.0357 - val_accuracy: 0.9883
# Epoch 10/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0380 - accuracy: 0.9869 - val_loss: 0.0349 - val_accuracy: 0.9884
# Epoch 11/100
# 63/63 [==============================] - 32s 502ms/step - loss: 0.0369 - accuracy: 0.9873 - val_loss: 0.0341 - val_accuracy: 0.9887
# Epoch 12/100
# 63/63 [==============================] - 32s 502ms/step - loss: 0.0327 - accuracy: 0.9884 - val_loss: 0.0315 - val_accuracy: 0.9887
# Epoch 13/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0338 - accuracy: 0.9879 - val_loss: 0.0335 - val_accuracy: 0.9879
# Epoch 14/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0307 - accuracy: 0.9889 - val_loss: 0.0350 - val_accuracy: 0.9876
# Epoch 15/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.0271 - val_accuracy: 0.9908
# Epoch 16/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0266 - accuracy: 0.9901 - val_loss: 0.0284 - val_accuracy: 0.9900
# Epoch 17/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0260 - accuracy: 0.9904 - val_loss: 0.0264 - val_accuracy: 0.9904
# Epoch 18/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0244 - accuracy: 0.9908 - val_loss: 0.0274 - val_accuracy: 0.9909
# Epoch 19/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0221 - accuracy: 0.9915 - val_loss: 0.0248 - val_accuracy: 0.9911
# Epoch 20/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0223 - accuracy: 0.9915 - val_loss: 0.0255 - val_accuracy: 0.9915
# Epoch 21/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0201 - accuracy: 0.9923 - val_loss: 0.0270 - val_accuracy: 0.9915
# Epoch 22/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0193 - accuracy: 0.9925 - val_loss: 0.0262 - val_accuracy: 0.9918
# Epoch 23/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0178 - accuracy: 0.9931 - val_loss: 0.0233 - val_accuracy: 0.9921
# Epoch 24/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0192 - accuracy: 0.9926 - val_loss: 0.0248 - val_accuracy: 0.9917
# Epoch 25/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0169 - accuracy: 0.9933 - val_loss: 0.0246 - val_accuracy: 0.9920
# Epoch 26/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0164 - accuracy: 0.9936 - val_loss: 0.0213 - val_accuracy: 0.9924
# Epoch 27/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0155 - accuracy: 0.9938 - val_loss: 0.0251 - val_accuracy: 0.9917
# Epoch 28/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0147 - accuracy: 0.9942 - val_loss: 0.0220 - val_accuracy: 0.9926
# Epoch 29/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0137 - accuracy: 0.9945 - val_loss: 0.0220 - val_accuracy: 0.9926
# Epoch 30/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0134 - accuracy: 0.9947 - val_loss: 0.0221 - val_accuracy: 0.9926
# Epoch 31/100
# 63/63 [==============================] - 32s 503ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 0.0216 - val_accuracy: 0.9927
# Epoch 32/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0138 - accuracy: 0.9945 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 33/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0129 - accuracy: 0.9949 - val_loss: 0.0240 - val_accuracy: 0.9926
# Epoch 34/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0120 - accuracy: 0.9952 - val_loss: 0.0248 - val_accuracy: 0.9929
# Epoch 35/100
# 63/63 [==============================] - 32s 502ms/step - loss: 0.0116 - accuracy: 0.9953 - val_loss: 0.0233 - val_accuracy: 0.9927
# Epoch 36/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.0240 - val_accuracy: 0.9930
# Epoch 37/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.0253 - val_accuracy: 0.9932
# Epoch 38/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0099 - accuracy: 0.9959 - val_loss: 0.0291 - val_accuracy: 0.9930
# Epoch 39/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0097 - accuracy: 0.9961 - val_loss: 0.0234 - val_accuracy: 0.9932
# Epoch 40/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0092 - accuracy: 0.9962 - val_loss: 0.0250 - val_accuracy: 0.9932
# Epoch 41/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0102 - accuracy: 0.9959 - val_loss: 0.0238 - val_accuracy: 0.9928
# Epoch 42/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0095 - accuracy: 0.9961 - val_loss: 0.0241 - val_accuracy: 0.9933
# Epoch 43/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0092 - accuracy: 0.9962 - val_loss: 0.0212 - val_accuracy: 0.9929
# Epoch 44/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 0.0237 - val_accuracy: 0.9924
# Epoch 45/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0103 - accuracy: 0.9959 - val_loss: 0.0240 - val_accuracy: 0.9929
# Epoch 46/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0092 - accuracy: 0.9962 - val_loss: 0.0244 - val_accuracy: 0.9932
# Epoch 47/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0235 - val_accuracy: 0.9932
# Epoch 48/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0082 - accuracy: 0.9966 - val_loss: 0.0233 - val_accuracy: 0.9935
# Epoch 49/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0253 - val_accuracy: 0.9936
# Epoch 50/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0073 - accuracy: 0.9970 - val_loss: 0.0251 - val_accuracy: 0.9934
# Epoch 51/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0271 - val_accuracy: 0.9930
# Epoch 52/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0233 - val_accuracy: 0.9933
# Epoch 53/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0074 - accuracy: 0.9969 - val_loss: 0.0238 - val_accuracy: 0.9934
# Epoch 54/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0071 - accuracy: 0.9970 - val_loss: 0.0255 - val_accuracy: 0.9935
# Epoch 55/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0101 - accuracy: 0.9960 - val_loss: 0.0239 - val_accuracy: 0.9930
# Epoch 56/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0086 - accuracy: 0.9965 - val_loss: 0.0253 - val_accuracy: 0.9935
# Epoch 57/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0246 - val_accuracy: 0.9933
# Epoch 58/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0075 - accuracy: 0.9969 - val_loss: 0.0277 - val_accuracy: 0.9932
# Epoch 59/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0261 - val_accuracy: 0.9933
# Epoch 60/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0266 - val_accuracy: 0.9934
# Epoch 61/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0067 - accuracy: 0.9972 - val_loss: 0.0267 - val_accuracy: 0.9933
# Epoch 62/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.0279 - val_accuracy: 0.9937
# Epoch 63/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.0273 - val_accuracy: 0.9936
# Epoch 64/100
# 63/63 [==============================] - 32s 504ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0243 - val_accuracy: 0.9934
# Epoch 65/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0279 - val_accuracy: 0.9936
# Epoch 66/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0270 - val_accuracy: 0.9936
# Epoch 67/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.0324 - val_accuracy: 0.9905
# Epoch 68/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0193 - accuracy: 0.9930 - val_loss: 0.0263 - val_accuracy: 0.9926
# Epoch 69/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0125 - accuracy: 0.9953 - val_loss: 0.0276 - val_accuracy: 0.9899
# Epoch 70/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.0245 - val_accuracy: 0.9930
# Epoch 71/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0231 - val_accuracy: 0.9932
# Epoch 72/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.0230 - val_accuracy: 0.9933
# Epoch 73/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0216 - val_accuracy: 0.9937
# Epoch 74/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0262 - val_accuracy: 0.9935
# Epoch 75/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0061 - accuracy: 0.9974 - val_loss: 0.0292 - val_accuracy: 0.9935
# Epoch 76/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0277 - val_accuracy: 0.9936
# Epoch 77/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.0262 - val_accuracy: 0.9935
# Epoch 78/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.0249 - val_accuracy: 0.9935
# Epoch 79/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.0265 - val_accuracy: 0.9934
# Epoch 80/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0274 - val_accuracy: 0.9936
# Epoch 81/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0314 - val_accuracy: 0.9936
# Epoch 82/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0051 - accuracy: 0.9978 - val_loss: 0.0272 - val_accuracy: 0.9936
# Epoch 83/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.0307 - val_accuracy: 0.9936
# Epoch 84/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0303 - val_accuracy: 0.9936
# Epoch 85/100
# 63/63 [==============================] - 31s 499ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0342 - val_accuracy: 0.9929
# Epoch 86/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.0276 - val_accuracy: 0.9932
# Epoch 87/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0061 - accuracy: 0.9975 - val_loss: 0.0287 - val_accuracy: 0.9935
# Epoch 88/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0293 - val_accuracy: 0.9934
# Epoch 89/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0300 - val_accuracy: 0.9933
# Epoch 90/100
# 63/63 [==============================] - 32s 501ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0252 - val_accuracy: 0.9928
# Epoch 91/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0373 - val_accuracy: 0.9915
# Epoch 92/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0109 - accuracy: 0.9960 - val_loss: 0.0261 - val_accuracy: 0.9928
# Epoch 93/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0275 - val_accuracy: 0.9934
# Epoch 94/100
# 63/63 [==============================] - 32s 499ms/step - loss: 0.0067 - accuracy: 0.9973 - val_loss: 0.0256 - val_accuracy: 0.9932
# Epoch 95/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0287 - val_accuracy: 0.9933
# Epoch 96/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.0269 - val_accuracy: 0.9932
# Epoch 97/100
# 63/63 [==============================] - 32s 500ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0287 - val_accuracy: 0.9931
# Epoch 98/100
# 63/63 [==============================] - 31s 497ms/step - loss: 0.0064 - accuracy: 0.9973 - val_loss: 0.0324 - val_accuracy: 0.9931
# Epoch 99/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0262 - val_accuracy: 0.9928
# Epoch 100/100
# 63/63 [==============================] - 31s 498ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0281 - val_accuracy: 0.9930

# %%
unet_model.save("")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# 2024-02-29 12:14:16.978437: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 18874368 exceeds 10% of free system memory.
# 2024-02-29 12:14:16.986339: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 37748736 exceeds 10% of free system memory.
# 2024-02-29 12:14:17.000029: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 18874368 exceeds 10% of free system memory.
# 2024-02-29 12:14:17.005630: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 18874368 exceeds 10% of free system memory.
# 2024-02-29 12:14:17.034993: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 18874368 exceeds 10% of free system memory.
# INFO:tensorflow:Assets written to: assets
# INFO:tensorflow:Assets written to: assets

# %%
def display_learning_curves(history):
    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    epochs_range = range(NUM_EPOCHS)

    fig = plt.figure(figsize=(12,6))

    plt.subplot(1,2,1)
    plt.plot(epochs_range, acc, label="train accuracy")
    plt.plot(epochs_range, val_acc, label="validataion accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(loc="lower right")

    plt.subplot(1,2,2)
    plt.plot(epochs_range, loss, label="train loss")
    plt.plot(epochs_range, val_loss, label="validataion loss")
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(loc="upper right")

    fig.tight_layout()
    plt.show()

# %%
# Display learning curves
display_learning_curves(unet_model.history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [54], line 2
#       1 # Display learning curves
# ----> 2 display_learning_curves(unet_model.history)
#
# Cell In [53], line 2, in display_learning_curves(history)
#       1 def display_learning_curves(history):
# ----> 2     acc = history.history["accuracy"]
#       3     val_acc = history.history["val_accuracy"]
#       5     loss = history.history["loss"]
#
# KeyError: 'accuracy'

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

def show_predictions(dataset=None, num=1):
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet_model.predict(image)
            display_2([image[0], mask[0], create_mask(pred_mask)])
    else:
        display_2([sample_image, sample_mask,
                 create_mask(model.predict(sample_image[tf.newaxis, ...]))])

# %%
test_batches = test_dataset.take(613).batch(1)
count = 0
for i in test_batches:
    count +=1

print("number of batches:", count)
# Out:
# number of batches: 613

# %%
def display_2(display_list):
    plt.figure(figsize=(5, 5))
    title = ["Input Image", "True Mask","Predicted_Mask"]
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap = 'gray')
        plt.axis("off")
    plt.show()

# %%
show_predictions(test_batches.take(5), 5)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
